# %%
from urbaning.data import download_one_sequence

download_one_sequence(download_dir="datasets/UrbanIng-V2X", sequence_name="20241126_0024_crossing1_09")
download_one_sequence(download_dir="datasets/UrbanIng-V2X", sequence_name="20241126_0008_crossing1_01")
download_one_sequence(download_dir="datasets/UrbanIng-V2X", sequence_name="20241127_0000_crossing1_00")
# Out:
# ...
# Downloaded : datasets/UrbanIng-V2X\dataset\20241126_0024_crossing1_09.7z.001
# ...
# Downloaded : datasets/UrbanIng-V2X\dataset\20241126_0024_crossing1_09.7z.002
# ...
# Downloaded : datasets/UrbanIng-V2X\labels\20241126_0024_crossing1_09.json
# ...
# Downloaded : datasets/UrbanIng-V2X\av_vehicle_data.json
# ...
# Downloaded : datasets/UrbanIng-V2X\crossings_lanelet2map.osm
# ...
# Downloaded : datasets/UrbanIng-V2X\labels_av_track_ids.json
#
# All files downloaded successfully.
# ...
# Downloaded : datasets/UrbanIng-V2X\dataset\20241126_0008_crossing1_01.7z.001
# ...
# Downloaded : datasets/UrbanIng-V2X\dataset\20241126_0008_crossing1_01.7z.002
# ...
# Downloaded : datasets/UrbanIng-V2X\labels\20241126_0008_crossing1_01.json
# Skipping File datasets/UrbanIng-V2X\av_vehicle_data.json has already been downloaded
# Skipping File datasets/UrbanIng-V2X\crossings_lanelet2map.osm has already been downloaded
# Skipping File datasets/UrbanIng-V2X\labels_av_track_ids.json has already been downloaded
#
# All files downloaded successfully.
# ...

# %%
from urbaning.data import unzip_dataset
unzip_dataset(dataset_folder="datasets/UrbanIng-V2X")
# Out:
# Unzipping (1 / 3): datasets/UrbanIng-V2X\dataset\20241126_0008_crossing1_01.7z.001 to datasets/UrbanIng-V2X\dataset\20241126_0008_crossing1_01
# Extracted datasets\UrbanIng-V2X\dataset\20241126_0008_crossing1_01.7z.001 to datasets\UrbanIng-V2X\dataset\20241126_0008_crossing1_01
# Unzipping (2 / 3): datasets/UrbanIng-V2X\dataset\20241126_0024_crossing1_09.7z.001 to datasets/UrbanIng-V2X\dataset\20241126_0024_crossing1_09
# Extracted datasets\UrbanIng-V2X\dataset\20241126_0024_crossing1_09.7z.001 to datasets\UrbanIng-V2X\dataset\20241126_0024_crossing1_09
# Unzipping (3 / 3): datasets/UrbanIng-V2X\dataset\20241127_0000_crossing1_00.7z.001 to datasets/UrbanIng-V2X\dataset\20241127_0000_crossing1_00
# Extracted datasets\UrbanIng-V2X\dataset\20241127_0000_crossing1_00.7z.001 to datasets\UrbanIng-V2X\dataset\20241127_0000_crossing1_00
